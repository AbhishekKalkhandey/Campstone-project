# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekKalkhandey/Campstone-project/blob/main/Mid_Course_Assessment_ML_Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Here is the ML case study project for RETAIL**

# %% [markdown]
# ## Define the Problem Statement

# %% [markdown]
# Before developing the solution, it is important to clearly define the problem within the retail market by understanding the industry dynamics and identifying the appropriate problem type, such as supervised or unsupervised learning. The primary focus is to comprehend the business objectives, including improving sales performance, customer retention, or demand forecasting, and to translate these goals into measurable outcomes. This stage also involves evaluating practical constraints such as data availability, budget, computational resources, and system limitations. Appropriate evaluation metrics are identified to track key performance indicators and assess model effectiveness. The relevance of the proposed model to the target audience is assessed, with particular emphasis on prediction accuracy and response time. Additionally, available data is analyzed to determine required features for effective modeling. Clearly defining the scope of the solution helps manage expectations and ensures alignment with business needs. Finally, suitable deployment options—such as cloud platforms, web applications, websites, or APIs—are considered to support real-time and scalable retail operations.

# %% [markdown]
# ## **Data Collection**

# %% [markdown]
# After defining the problem, the next step involves a thorough assessment of data requirements to ensure the solution effectively addresses the retail market challenges. Reliable data sources such as databases, APIs, surveys, and publicly available platforms are evaluated, along with the required data volume needed for meaningful analysis. The data is classified as labeled or unlabeled based on the problem type, while careful attention is given to data quality, including errors, bias, missing values, and consistency. Data relevancy is ensured by aligning features directly with retail objectives such as sales trends, customer behavior, and inventory patterns. Temporal effects and seasonal variations are considered to capture changes in customer demand over time. Legal and ethical concerns related to data privacy are addressed through appropriate sampling strategies and data anonymization techniques. Suitable tools are selected for efficient data collection and management, and version control mechanisms are implemented to track dataset changes. After evaluating all these requirements, it was determined that a retail dataset sourced from the online platform Kaggle satisfies the necessary criteria, providing sufficient volume, relevant features, and reliable structure to effectively support analysis and solution development for the retail market problem.

# %% [markdown]
# ### Load Data

# %%
import pandas as pd

df=pd.read_csv('/content/retail_sales_dataset.csv')
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# ### **Missing Values**

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.fillna(0)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
df.dropna()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %% [markdown]
# ### Outliner

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# Age is taken for Y axis because in retail purchase patter is directly realted to human age shows ous the input in their pattern .

# %%
y=df['Age']
y
# Out:
# 0      34
# 1      26
# 2      50
# 3      37
# 4      30
#        ..
# 995    62
# 996    52
# 997    23
# 998    36
# 999    47
# Name: Age, Length: 1000, dtype: int64

# %% [markdown]
# ### Univariate Outliner Detection

# %%
df['Age'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# As of NO Outliner found

# %% [markdown]
# ### Encode categorical variables

# %%
import pandas as pd
import numpy as np

# %%
df.head()

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %%
pd.get_dummies(df,columns=['Product Category'],drop_first=True)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age  Quantity  \
# 0                 1  2023-11-24     CUST001    Male   34         3
# 1                 2  2023-02-27     CUST002  Female   26         2
# 2                 3  2023-01-13     CUST003    Male   50         1
# 3                 4  2023-05-21     CUST004    Male   37         1
# 4                 5  2023-05-06     CUST005    Male   30         2
# ..              ...         ...         ...     ...  ...       ...
# 995             996  2023-05-16     CUST996    Male   62         1
# 996             997  2023-11-17     CUST997    Male   52         3
# 997             998  2023-10-29     CUST998  Female   23         4
# 998             999  2023-12-05     CUST999  Female   36         3
# 999            1000  2023-04-12    CUST1000    Male   47         4
#
#      Price per Unit  Total Amount  Product Category_Clothing  \
# 0                50           150                      False
# ...

# %% [markdown]
# ### Transform data

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
from sklearn.preprocessing import MinMaxScaler
scaling=MinMaxScaler()
scaling.fit_transform(df[['Price per Unit','Total Amount']])
# Out:
# array([[0.05263158, 0.06329114],
#        [1.        , 0.49367089],
#        [0.01052632, 0.00253165],
#        ...,
#        [0.        , 0.03797468],
#        [0.05263158, 0.06329114],
#        [0.01052632, 0.04810127]])

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %% [markdown]
# ### Statistics Summary

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Explore relationships between variables through scatter plots and bar charts

# %%
plt.scatter(df['Age'],df['Total Amount'])

# %%
plt.scatter(df['Age'],df['Quantity'])

# %%
plt.bar(df['Gender'],df['Total Amount'])
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.bar(df['Product Category'],df['Price per Unit'])
# Out:
# <BarContainer object of 1000 artists>

# %% [markdown]
# ### Heatmaps and Pair plots

# %%
import seaborn as sns

# %%
sns.pairplot(df, kind="reg")
plt.show()

# %%
corr=df[['Age','Quantity','Price per Unit','Total Amount']].corr()
sns.heatmap(corr,annot=True)
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ## Model Selection, Training & Evaluation

# %% [markdown]
# ### Split data into training and testing sets

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
x=df[['Quantity','Total Amount']]
y=df[['Age','Price per Unit']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train
# Out:
#      Quantity  Total Amount
# 505         3          1500
# 256         4          2000
# 611         1           500
# 1           2          1000
# 530         1           500
# ..        ...           ...
# 38          4           120
# 98          4          1200
# 431         2          1000
# 325         3            75
# 799         4          1200
#
# [700 rows x 2 columns]

# %%
y_train
# Out:
#      Age  Price per Unit
# 505   34             500
# 256   19             500
# 611   61             500
# 1     26             500
# 530   31             500
# ..   ...             ...
# 38    23              30
# 98    50             300
# 431   60             500
# 325   18              25
# 799   32             300
#
# [700 rows x 2 columns]

# %%
x_test
# Out:
#      Quantity  Total Amount
# 96          2          1000
# 127         1           500
# 401         2           600
# 2           1            30
# 312         3          1500
# ..        ...           ...
# 570         1            50
# 907         4          1200
# 467         1            25
# 487         3           900
# 214         3          1500
#
# [300 rows x 2 columns]

# %%
y_test
# Out:
#      Age  Price per Unit
# 96    51             500
# 127   25             500
# 401   41             300
# 2     50              30
# 312   55             500
# ..   ...             ...
# 570   41              50
# 907   46             300
# 467   40              25
# 487   51             300
# 214   58             500
#
# [300 rows x 2 columns]

# %%
clf.predict(x_test)
# Out:
# array([[ 40.41109804, 387.08516422],
#        [ 41.02759332, 279.73934202],
#        [ 40.85419118, 255.72299227],
#        [ 41.54822776, 125.38878997],
#        [ 39.79460276, 494.43098642],
#        [ 41.40805761,  91.52027733],
#        [ 41.55376642, 123.74676282],
#        [ 41.26064525, -15.62539956],
#        [ 41.29004212,  51.08365608],
#        [ 41.35650609,  31.37933029],
#        [ 41.40805761,  91.52027733],
#        [ 41.35650609,  31.37933029],
#        [ 41.5260731 , 131.95689857],
#        [ 41.24913989, 214.05825604],
#        [ 41.29004212,  51.08365608],
#        [ 41.5260731 , 131.95689857],
#        [ 41.45236692,  78.38406013],
#        [ 40.45924248, 297.38772849],
#        [ 41.35650609,  31.37933029],
#        [ 40.06429377, 339.05246471],
#        [ 41.28279991, -22.19350815],
#        [ 41.24913989, 214.05825604],
#        [ 41.46344425,  75.10000583],
#        [ 41.46344425,  75.10000583],
#        [ 41.54822776, 125.38878997],
# ...

# %%
clf.score(x_test,y_test)
# Out:
# 0.41174458164226563
